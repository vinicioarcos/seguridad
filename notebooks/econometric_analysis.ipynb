# %% [markdown]
# # Análisis econométrico
#
# Revisar los modelos reproducibles de `scripts/econometric_model.py`. Toda estimación es exploratoria y no causal.

# %%
from pathlib import Path
import json

root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
path = root / 'outputs/tables/econometric_results.json'
json.loads(path.read_text(encoding='utf-8')) if path.exists() else 'Ejecute el modelo primero'
