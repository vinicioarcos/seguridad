# %% [markdown]
# # Análisis exploratorio
#
# Ejecutar después de aprobar `validate_data`. No modificar datos crudos desde el notebook.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
df = pd.read_csv(root / 'data/processed/indicators.csv')
df.groupby(['country', 'indicator'])['value'].describe()
